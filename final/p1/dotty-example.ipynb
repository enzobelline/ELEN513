# %%
from graphviz import Digraph
# Create Digraph object
dot = Digraph()
# Add nodes 1 and 2
dot.node('A1','ADD')
dot.node('S1','SUB')

# Add edge between 1 and 2
dot.edge('A1', 'S1')
# Visualize the graph
dot

# %%
from graphviz import Digraph
dot = Digraph()
dot.node('s1', 't1=LOAD(x);')
dot.node('s2', 't2=t1+4;')
dot.node('s3', 't3=t1*8;')
dot.node('s4', 't4=t1-4;')
dot.node('s5', 't5=t1/2;')
dot.node('s6', 't6=t2*t3;')
dot.node('s7', 't7=t4-t5;')
dot.node('s8', 't8=t6*t7;')
dot.node('s9', 'STORE(y,t8);')

dot.edge('s1','s2')
dot.edge('s1','s3')
dot.edge('s1','s4')
dot.edge('s1','s5')
dot.edge('s2','s6')
dot.edge('s3','s6')
dot.edge('s4','s7')
dot.edge('s5','s7')
dot.edge('s6','s8')
dot.edge('s7','s8')
dot.edge('s8','s9')
dot
